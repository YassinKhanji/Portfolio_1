# %%
import pandas as pd
import numpy as np
from data import Data
import datetime as dt
# Out:
# Skipping category 'layer-1', already processed.
# Skipping category 'depin', already processed.
# Skipping category 'proof-of-work-pow', already processed.
# Skipping category 'proof-of-stake-pos', already processed.
# Skipping category 'meme-token', already processed.
# Skipping category 'dog-themed-coins', already processed.
# Skipping category 'eth-2-0-staking', already processed.
# Skipping category 'non-fungible-tokens-nft', already processed.
# Skipping category 'governance', already processed.
# Skipping category 'artificial-intelligence', already processed.
# Skipping category 'infrastructure', already processed.
# Skipping category 'layer-2', already processed.
# Skipping category 'zero-knowledge-zk', already processed.
# Skipping category 'storage', already processed.
# Skipping category 'oracle', already processed.
# Skipping category 'bitcoin-fork', already processed.
# Skipping category 'restaking', already processed.
# Skipping category 'rollup', already processed.
# Skipping category 'metaverse', already processed.
# Skipping category 'privacy-coins', already processed.
# Skipping category 'layer-0-l0', already processed.
# Skipping category 'solana-meme-coins', already processed.
# Skipping category 'data-availability', already processed.
# Skipping category 'internet-of-things-iot', already processed.
# Skipping category 'frog-themed-coins', already processed.
# Skipping category 'ai-agents', already processed.
# Skipping category 'superchain-ecosystem', already processed.
# Skipping category 'bitcoin-layer-2', already processed.
# Skipping category 'bridge-governance-tokens', already processed.
# Skipping category 'modular-blockchain', already processed.
# Skipping category 'cat-themed-coins', already processed.
# Skipping category 'cross-chain-communication', already processed.
# Skipping category 'analytics', already processed.
# Skipping category 'identity', already processed.
# Skipping category 'wallets', already processed.
# Skipping category 'masternodes', already processed.
# ['BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'SOLUSDT', 'ADAUSDT', 'TRXUSDT', 'AVAXUSDT', 'TONUSDT', 'SUIUSDT', 'HBARUSDT', 'HYPEUSDT', 'BCHUSDT', 'NEARUSDT', 'APTUSDT', 'ICPUSDT', 'CROUSDT', 'VETUSDT', 'XMRUSDT', 'TAOUSDT', 'OMUSDT', 'FILUSDT', 'KASUSDT', 'ALGOUSDT', 'FTMUSDT', 'TIAUSDT', 'THETAUSDT', 'INJUSDT', 'SEIUSDT', 'GALAUSDT', 'FLRUSDT', 'FTNUSDT', 'XTZUSDT', 'KAIAUSDT', 'FLOWUSDT', 'DYDXUSDT', 'ARUSDT', 'IOTAUSDT', 'COREUSDT', 'AIOZUSDT', 'EGLDUSDT', 'CHZUSDT', 'RONUSDT', 'GNOUSDT', 'XECUSDT', 'VANAUSDT', 'ROSEUSDT', 'KAVAUSDT', 'ASTRUSDT', 'RBNTUSDT', 'VRSCUSDT', 'ENJUSDT', 'CELOUSDT', 'ONEUSDT', 'PEAQUSDT', 'QUBICUSDT', 'WEMIXUSDT', 'ZETAUSDT', 'ELFUSDT', 'ALEOUSDT', 'KDAUSDT', 'POLYXUSDT', 'XCHUSDT', 'DCRUSDT', 'XRDUSDT', 'SKLUSDT', 'SUPRAUSDT', 'GLMRUSDT', 'VANRYUSDT', 'HEARTUSDT', 'CSPRUSDT', 'DAGUSDT', 'CHRUSDT', 'BBUSDT', 'ZANOUSDT', 'SAGAUSDT', 'HIVEUSDT', 'WAXPUSDT', 'ALPHUSDT', 'ORAIUSDT', 'ERGUSDT', 'ONGUSDT', 'MOVRUSDT', 'AZEROUSDT', 'QANXUSDT', 'DUSKUSDT', 'TLOSUSDT', 'SYSUSDT', 'OMNIUSDT', 'KUJIUSDT', 'LYXUSDT', 'PEPUSDT', 'XIONUSDT', 'CUDOSUSDT', 'NGLUSDT', 'LTOUSDT', 'OASUSDT', 'CTXCUSDT', 'REIUSDT', 'ROOTUSDT', 'ELAUSDT']
# The file contains content.

# %%
def trades(df):
    df = df.unstack()

    for coin in df['close'].columns:
        df['trades', coin] = df['position', coin].diff().fillna(0).abs()

    #A case where we start with a position, we need to add a trade
    for coin in df['close'].columns:
        if df['position', coin].iloc[0] ==1:
            first_date = df.index[0]
            df.loc[first_date, ('close', coin)]= 1
    df = df.stack(future_stack=True)
    return df

# %%
symbols = ['BTCUSDT', 'ETHUSDT']
interval = '1h'
start_time = dt.datetime(2021, 1, 1)
end_time = dt.datetime(2021, 1, 10)
data = Data(symbols, interval, start_time, end_time).df
data
# Out:
# c:\Users\yassi\OneDrive\Documents\GitHub\Portfolio_1\Technical_Portfolio\Data_Management\data.py:87: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df = df.stack(level=1)
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  29409.99  1.014308  29470.00    0.014207
#                     ETHUSDT    748.28  1.019358    749.00    0.019173
# 2021-01-01 02:00:00 BTCUSDT  29194.65  1.006881  29465.26   -0.007349
#                     ETHUSDT    744.06  1.013609    749.00   -0.005656
# 2021-01-01 03:00:00 BTCUSDT  29278.40  1.009770  29367.00    0.002865
# ...                               ...       ...       ...         ...
# 2021-01-09 21:00:00 ETHUSDT   1287.96  1.754547   1294.18    0.013145
# 2021-01-09 22:00:00 BTCUSDT  40281.09  1.389236  40743.47   -0.010808
#                     ETHUSDT   1286.61  1.752708   1304.37   -0.001049
# 2021-01-09 23:00:00 BTCUSDT  40088.22  1.382585  40415.01   -0.004800
#                     ETHUSDT   1276.00  1.738254   1292.74   -0.008281
#
#                                   low      open     price   returns  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  28960.35  28995.13  29409.99  0.014308
#                     ETHUSDT    733.37    734.08    748.28  0.019358
# 2021-01-01 02:00:00 BTCUSDT  29120.03  29410.00  29194.65 -0.007322
#                     ETHUSDT    742.27    748.27    744.06 -0.005640
# 2021-01-01 03:00:00 BTCUSDT  29150.02  29195.25  29278.40  0.002869
# ...                               ...       ...       ...       ...
# 2021-01-09 21:00:00 ETHUSDT   1261.50   1271.14   1287.96  0.013232
# 2021-01-09 22:00:00 BTCUSDT  40120.00  40718.81  40281.09 -0.010750
#                     ETHUSDT   1276.32   1287.95   1286.61 -0.001048
# 2021-01-09 23:00:00 BTCUSDT  39928.91  40283.73  40088.22 -0.004788
#                     ETHUSDT   1266.85   1286.65   1276.00 -0.008246
#
#                                     volume  volume_in_dollars
# date                coin
# 2021-01-01 01:00:00 BTCUSDT    5403.068471       1.589042e+08
#                     ETHUSDT   52336.187790       3.916212e+07
# 2021-01-01 02:00:00 BTCUSDT    2384.231560       6.960681e+07
#                     ETHUSDT   33019.501000       2.456849e+07
# 2021-01-01 03:00:00 BTCUSDT    1461.345077       4.278585e+07
# 2021-01-01 04:00:00      5.955236e+07  1.395071e+07     2.0     2.0
# 2021-01-01 05:00:00      4.290363e+07  1.107143e+07     3.0     3.0
# 2021-01-01 06:00:00      4.144877e+07  1.265866e+07     3.0     3.0
# 2021-01-01 07:00:00      6.924620e+07  1.594561e+07     3.0     3.0
# 2021-01-01 08:00:00      5.823683e+07  3.868791e+07     3.0     3.0
# 2021-01-01 09:00:00      5.904850e+07  1.675466e+07     3.0     3.0
# 2021-01-01 10:00:00      5.681858e+07  1.686970e+07     4.0     4.0
#
# [10 rows x 28 columns]

# %%
df['session'].groupby('BTCUSDT').count()
# Out:
# coin     ETHUSDT
# BTCUSDT
# 0.0            2
# 1.0            1
# 2.0            1
# 3.0            5
# 4.0            3
# ...          ...
# 93.0           3
# 94.0           3
# 95.0           1
# 96.0           1
# 97.0           1
#
# [98 rows x 1 columns]

# %%
# Assuming 'strategy' is a top-level column, and 'coin' is a second-level column
for coin in df.columns.levels[1]:
    df[('session_compound', coin)] = df['log_return', coin].groupby(df['session', coin]).cumsum().apply(np.exp) - 1
df
# Out:
#                         close           creturns                high           \
# coin                  BTCUSDT  ETHUSDT   BTCUSDT   ETHUSDT   BTCUSDT  ETHUSDT
# date
# 2021-01-01 01:00:00  29409.99   748.28  1.014308  1.019358  29470.00   749.00
# 2021-01-01 02:00:00  29194.65   744.06  1.006881  1.013609  29465.26   749.00
# 2021-01-01 03:00:00  29278.40   744.82  1.009770  1.014644  29367.00   747.23
# 2021-01-01 04:00:00  29220.31   742.29  1.007766  1.011198  29395.00   747.09
# 2021-01-01 05:00:00  29187.01   740.65  1.006618  1.008964  29235.28   743.23
# ...                       ...      ...       ...       ...       ...      ...
# 2021-01-09 19:00:00  40665.91  1229.42  1.402508  1.674799  40880.00  1235.69
# 2021-01-09 20:00:00  40606.22  1271.14  1.400450  1.731633  40781.69  1272.00
# 2021-01-09 21:00:00  40718.80  1287.96  1.404332  1.754547  40755.00  1294.18
# 2021-01-09 22:00:00  40281.09  1286.61  1.389236  1.752708  40743.47  1304.37
# 2021-01-09 23:00:00  40088.22  1276.00  1.382585  1.738254  40415.01  1292.74
#
#                     log_return                 low           ...  trades  \
# coin                   BTCUSDT   ETHUSDT   BTCUSDT  ETHUSDT  ... BTCUSDT
# date                                                         ...
# 2021-01-01 01:00:00   0.014207  0.019173  28960.35   733.37  ...     0.0
# 2021-01-01 02:00:00  -0.007349 -0.005656  29120.03   742.27  ...     1.0
# 2021-01-01 03:00:00   0.002865  0.001021  29150.02   743.10  ...     1.0
# 2021-01-01 04:00:00  -0.001986 -0.003403  29029.40   739.30  ...     1.0
# 2021-01-01 05:00:00  -0.001140 -0.002212  29084.11   739.50  ...     0.0
# ...                        ...       ...       ...      ...  ...     ...
# 2021-01-09 19:00:00   0.000391  0.003855  40469.40  1220.48  ...     0.0
# 2021-01-09 20:00:00  -0.001469  0.033372  40050.00  1217.54  ...     1.0
# 2021-01-09 21:00:00   0.002769  0.013145  40483.17  1261.50  ...     1.0
# 2021-01-09 22:00:00  -0.010808 -0.001049  40120.00  1276.32  ...     1.0
# 2021-01-09 23:00:00  -0.004800 -0.008281  39928.91  1266.85  ...     0.0
#
#                                   volume               volume_in_dollars  \
# coin                ETHUSDT      BTCUSDT       ETHUSDT           BTCUSDT
# date
# 2021-01-01 01:00:00     0.0  5403.068471   52336.18779      1.589042e+08
# 2021-01-01 02:00:00     1.0  2384.231560   33019.50100      6.960681e+07
# 2021-01-01 03:00:00     1.0  1461.345077   17604.80859      4.278585e+07
# 2021-01-01 04:00:00     1.0  2038.046803   18794.15424      5.955236e+07
# 2021-01-01 05:00:00     0.0  1469.956262   14948.26447      4.290363e+07
# ...                     ...          ...           ...               ...
# 2021-01-09 19:00:00     0.0  1864.142493   36022.81451      7.580705e+07
# 2021-01-09 20:00:00     0.0  3330.651765  116955.13239      1.352452e+08
# 2021-01-09 21:00:00     0.0  2433.809430  139273.22601      9.910180e+07
# 2021-01-09 22:00:00     1.0  1973.252287   84360.71587      7.948475e+07
# 2021-01-09 23:00:00     0.0  3255.535761   64558.95579      1.305086e+08
#
#                                   session         session_compound
# coin                      ETHUSDT BTCUSDT ETHUSDT          BTCUSDT   ETHUSDT
# date
# 2021-01-01 01:00:00  3.916212e+07     0.0     0.0         0.014308  0.019358
# 2021-01-01 02:00:00  2.456849e+07     0.0     0.0         0.006881  0.013609
# 2021-01-01 03:00:00  1.311241e+07     1.0     1.0         0.002869  0.001021
# 2021-01-01 04:00:00  1.395071e+07     2.0     2.0        -0.001984 -0.003397
# 2021-01-01 05:00:00  1.107143e+07     3.0     3.0        -0.001140 -0.002209
# ...                           ...     ...     ...              ...       ...
# 2021-01-09 19:00:00  4.428717e+07    94.0   106.0         0.006049  0.005644
# 2021-01-09 20:00:00  1.486663e+08    94.0   106.0         0.004572  0.039770
# 2021-01-09 21:00:00  1.793783e+08    95.0   106.0         0.002772  0.053529
# 2021-01-09 22:00:00  1.085393e+08    96.0   106.0        -0.010750  0.052425
# 2021-01-09 23:00:00  8.237723e+07    97.0   107.0        -0.004788 -0.008246
#
# [215 rows x 30 columns]

# %%
df[('overall_session_return', 'BTCUSDT')] = df['strategy', 'BTCUSDT'].groupby(df['session', 'BTCUSDT']).transform(lambda x: (x + 1).prod() - 1)
df['overall_session_return']
# Out:
# coin                  BTCUSDT
# date
# 2021-01-01 01:00:00  0.000000
# 2021-01-01 02:00:00  0.000000
# 2021-01-01 03:00:00  0.002869
# 2021-01-01 04:00:00  0.000000
# 2021-01-01 05:00:00 -0.000619
# ...                       ...
# 2021-01-09 19:00:00  0.000000
# 2021-01-09 20:00:00  0.000000
# 2021-01-09 21:00:00  0.002772
# 2021-01-09 22:00:00  0.000000
# 2021-01-09 23:00:00 -0.004788
#
# [215 rows x 1 columns]

# %% [markdown]
# Putting everything together

# %%
def sessions(df):
    _df = df.copy().unstack()
    for coin in _df['close'].columns:
        _df['session', coin] = np.sign(_df['trades', coin]).cumsum().shift().fillna(0)
        _df[('session_compound', coin)] = _df['strategy', coin].groupby(_df['session', coin]).cumsum().apply(np.exp)
        _df[('overall_session_return', coin)] = _df['session_compound', coin].groupby(_df['session', coin]).transform(lambda x: x.iloc[-1] - 1)
    
    _df = _df.stack(future_stack=True)

    return _df

# %%
test = sessions(df.stack())
test
# Out:
# C:\Users\yassi\AppData\Local\Temp\ipykernel_26900\2050970863.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#
#                     ETHUSDT       1.085393e+08    106.0          1.000000
# 2021-01-09 23:00:00 BTCUSDT       1.305086e+08     97.0          0.995223
#                     ETHUSDT       8.237723e+07    107.0          0.991787
#
#                              overall_session_return
# date                coin
# 2021-01-01 01:00:00 BTCUSDT                0.000000
#                     ETHUSDT                0.000000
# 2021-01-01 02:00:00 BTCUSDT                0.000000
#                     ETHUSDT                0.000000
# 2021-01-01 03:00:00 BTCUSDT                0.002873
# ...                                             ...
# 2021-01-09 21:00:00 ETHUSDT                0.000000
# 2021-01-09 22:00:00 BTCUSDT                0.000000
#                     ETHUSDT                0.000000
# 2021-01-09 23:00:00 BTCUSDT               -0.004777
#                     ETHUSDT               -0.008213
#
# [430 rows x 16 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Metrics

# %% [markdown]
# Here is just a few of the metrics that we need to test as they are not implemented in other libraries or does not reflect the value that we are looking for (such as winrate, for qs it is the number of days that were up whereas we want the number of trades that were up)

# %%
import math
def calculate_trades_win_rate(df):
    results = {}
    for coin in df['strategy'].columns:
        winning_trades = (df['overall_session_return', coin] > 0).sum()
        total_trades = math.ceil(df['session', coin].iloc[-1] / 2) #we divide by 2 because a session can indicates being in a trade and not being in a trade
        results[coin] = round(winning_trades / total_trades, 2)

    return results

# %%
calculate_trades_win_rate(test.unstack())['BTCUSDT']
# Out:
# 0.8

# %%
def calculate_avg_trade_return(df):
    results = {}
    for coin in df['strategy'].columns:
        active_trades = df[df['position', coin] == 1]
        expectancy = active_trades['overall_session_return', coin].mean()
        results[coin] = expectancy

    return results

# %%
calculate_avg_trade_return(test.unstack())
# Out:
# {'BTCUSDT': -0.006832893276774197, 'ETHUSDT': -0.006457835487248825}

# %%
def calculate_expectancy(df):
    results = {}
    for coin in df['strategy'].columns:
        win_rate = calculate_trades_win_rate(df)[coin]
        losing_rate = 1 - win_rate
        average_win = df[(df['position', coin] == 1) & (df['overall_session_return', coin] >= 0)]['overall_session_return', coin].mean()
        average_loss = df[(df['position', coin] == 1) & (df['overall_session_return', coin] <= 0)]['overall_session_return', coin].mean()
        expectancy = (win_rate * average_win) - (losing_rate * average_loss)
        results[coin] = expectancy

    return results

# %%
calculate_expectancy(test.unstack())
# Out:
# {'BTCUSDT': 0.0021203881611367033, 'ETHUSDT': 0.0016135017960747533}

# %%
coin = 'BTCUSDT'
df[(df['position', coin] == 1) & (df['overall_session_return', coin] > 0)]['overall_session_return', coin].mean()
# Out:
# 0.005463569772552785

# %%
def calculate_max_dd_duration(df):
    """
    The maximum drawdown duration is the time it takes for the strategy to recover from a drawdown (does not have to be the maximum)

    Typically 3 - 6 months is considered to be good for a maximum duration
    """
    results = {}
    for coin in df['strategy'].columns:
        series = df['strategy', coin]
        creturns = series.cumsum().apply(np.exp)
        cummax = creturns.cummax()
        drawdown = (cummax - creturns)/cummax

        begin = drawdown[drawdown == 0].index
        end = begin[1:]
        end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
        periods = end - begin
        results[coin] = periods.mean()

    return results

# %%
calculate_max_dd_duration(test.unstack())
# Out:
# {'BTCUSDT': Timedelta('0 days 04:20:48.979591836'),
#  'ETHUSDT': Timedelta('0 days 02:05:17.647058823')}

# %%
df = test.unstack()
results = {}
for coin in df['strategy'].columns:
    series = df['strategy', coin]
    creturns = series.cumsum().apply(np.exp)
    cummax = creturns.cummax()
    drawdown = (cummax - creturns)/cummax

    #We are basically calculating the time difference between peaks
    begin = drawdown[drawdown == 0].index
    end = begin[1:]
    end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
    periods = end - begin
    results[coin] = periods.max()

# %%
import quantstats_lumi as qs
class Metrics():

    def __init__(self, df):

        self.df = df.copy().unstack()

        # This would give the number of time periods in a year (e.g. monthly data would be 12)
        self.tp_year = (self.df['close'].count() / ((self.df.index[-1] - self.df.index[0]).days / 365.25))

    def print_performance(self, coin):
        ''' 
        Calculates and prints various Performance Metrics.

        The coin desired must be specified.
        '''
        
        strategy_multiple =     round(self.calculate_multiple(bh = False)[coin], 6)
        bh_multiple =           round(self.calculate_multiple(bh = True)[coin], 6)
        outperf =               round(strategy_multiple - bh_multiple, 6)
        cagr =                  round(self.calculate_cagr()[coin], 6)
        ann_mean =              round(self.calculate_annualized_mean()[coin], 6)
        ann_std =               round(self.calculate_annualized_std()[coin], 6)
        sharpe =                round(self.calculate_sharpe()[coin], 6)
        sortino =               round(self.calculate_sortino()[coin], 6)
        max_drawdown =          round(self.calculate_max_drawdown()[coin], 6)
        calmar =                round(self.calculate_calmar()[coin], 6)
        max_dd_duration =       round(self.calculate_max_dd_duration()[coin], 6)
        avg_dd_duration =       round(self.calculate_avg_dd_duration()[coin], 6)
        kelly_criterion =       round(self.calculate_kelly_criterion()[coin], 6)
        volatility =            round(self.calculate_volatility()[coin], 6)
        win_rate =              round(self.calculate_trades_win_rate()[coin], 2)
        daily_win_rate =        round(self.calculate_daily_win_rate()[coin], 6)
        avg_win =               round(self.calculate_avg_win()[coin], 6)
        avg_loss =              round(self.calculate_avg_loss()[coin], 6)
        avg_return_per_trade =  round(self.calculate_avg_return_per_trade()[coin], 6)
        percentage_expectancy = round(self.calculate_percentage_expectancy()[coin], 6)
        monthly_expectancy =    round(self.calculate_monthly_expectancy()[coin], 6)

        
        print(100 * "=")
        print("\n")
        print(f"All coins: {list(self.df.columns.get_level_values(1).unique())}")
        print("\n")
        print("From all available coins: {} was chosen".format(coin))
        print(100 * "-")
        print("\n")
        print("PERFORMANCE MEASURES:")
        print("\n")
        print("Multiple (Strategy):         {}".format(strategy_multiple))
        print("Multiple (Buy-and-Hold):     {}".format(bh_multiple))
        print(38 * "-")
        print("Out-/Underperformance:       {}".format(outperf))
        print("\n")
        print("CAGR:                        {}".format(cagr))
        print("Annualized Mean:             {}".format(ann_mean))
        print("Annualized Std:              {}".format(ann_std))
        print("Sharpe Ratio:                {}".format(sharpe))
        print("Sortino Ratio:               {}".format(sortino))
        print("Maximum Drawdown:            {}".format(max_drawdown))
        print("Calmar Ratio:                {}".format(calmar))
        print("Max Drawdown Duration:       {} Days".format(max_dd_duration))
        print("Average Drawdown Duration:   {} Days".format(avg_dd_duration))
        print("Volatility:                  {} Days".format(volatility))
        print("Win Rate:                    {}".format(win_rate))
        print("Daily Win Rate:              {}".format(daily_win_rate))
        print("Average Win:                 {}".format(avg_win))
        print("Average Loss:                {}".format(avg_loss))
        print("Average Return per Trade:    {}".format(avg_return_per_trade))
        print("Percentage Expectancy:       {}".format(percentage_expectancy))
        print("Monthly Expectancy:          {}".format(monthly_expectancy))
        print("Kelly Criterion:             {}".format(kelly_criterion))
        
        print(100 * "=")

    def calculate_multiple(self, bh = False):
        """
        The multiple is a measure of the total return of the strategy.

        Typically >1 is considered good, <1 should not be considered.
        """


        results = {}
        for coin in self.df['strategy'].columns:
            if bh:
                series = self.df['returns', coin]
            else:
                series = self.df['strategy', coin]
                
            results[coin] = np.exp(series.sum()) 

        return results

    def calculate_annualized_mean(self):
        """
        The annualized mean is a measure of the average return of the strategy.

        Typically >10% is considered good for Bull Markets, >2 - 3% for Bear Markets.
        """ 
    
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = self.df['strategy', coin].mean() * self.tp_year[coin]

        return results
    
    def calculate_annualized_std(self):
        """
        The standard deviation is a measure of the dispersion of returns.

        Typically <20% is considered good for Bull Markets, <10% for Bear Markets (even for aggressive portfolios)
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = self.df['strategy', coin].std() * np.sqrt(self.tp_year[coin])

        return results

    def calculate_max_dd_duration(self):
        """
        The maximum drawdown duration is the time it takes for the strategy to recover from a drawdown (does not have to be the maximum)

        Typically 3 - 6 months is considered to be good for a maximum duration
        """
        results = {}
        for coin in self.df['strategy'].columns:
            series = self.df['strategy', coin]
            creturns = series.cumsum().apply(np.exp)
            cummax = creturns.cummax()
            drawdown = (cummax - creturns)/cummax

            begin = drawdown[drawdown == 0].index
            end = begin[1:]
            end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
            periods = end - begin
            results[coin] = periods.max().days

        return results

    def calculate_avg_dd_duration(self):
        """
        The average drawdown duration is the average time it takes for the strategy to recover from a drawdown.

        Typically 1 - 3 months is considered to be good for an average duration
        
        """
        results = {}
        for coin in self.df['strategy'].columns:
            series = self.df['strategy', coin]
            creturns = series.cumsum().apply(np.exp)
            cummax = creturns.cummax()
            drawdown = (cummax - creturns)/cummax

            begin = drawdown[drawdown == 0].index
            end = begin[1:]
            end = end.append(pd.DatetimeIndex([drawdown.index[-1]]))
            periods = end - begin
            results[coin] = periods.mean().days

        return results
            

    def calculate_cagr(self):
        """"
        Compound Annual Growth Rate (CAGR) measures the mean annual growth rate of an investment
         over a specified time period longer than one year.

        CAGR is really dependent on the investment vehicule. For example, for a stock, 10%-15% is considered good.
        For crypto, it is much higher, typically >50%.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.cagr(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_volatility(self):
        """
        Volatility is a measure of the dispersion of returns. It is a measure of the risk of the strategy.

        Investors typically prefer lower volatility between 10-15% for the overall portfolio
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.volatility(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_sharpe(self):
        """
        Sharpe Ratio measures the excess return (or risk premium) per unit of total volatility (both upside and downside)
        Some may refer to it as the smoothness of the equity curve.

        Typically >1 is considered good for both trend-following and mean-reversion. <0.5 should not be considered
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.sharpe(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_sortino(self):
        """
        Sortino ratio is a variation of the Sharpe ratio that only factors in the downside risk.

        Typically >1.5 for both trend-following and mean-reversion.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.sortino(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_max_drawdown(self):
        """
        Depends on the strategy used. Typically <20% for trend-following, <10% for mean-reversion.
        Depends on the investor's risk tolerance. Typically <30% should not be considered.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.max_drawdown(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_calmar(self):
        """
        calmar = Annualized return / Max Drawdown

        Typically >1 for trend-following, >1.5 for mean-reversion.

        A calmar ration less than 1 should not be considered.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.calmar(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_kelly_criterion(self):
        """
        This is a measure of the optimal bet size that a trader should make.
        The higher, the better.

        Typically Values should be positive, generally between 0.1 and 0.5.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.kelly_criterion(self.df['strategy', coin].apply(np.exp) - 1) 
        
        return results
    
    def calculate_trades_win_rate(self):
        """
        Typically >50% for mean-reversion and anything for trend-following.
        (depends on the profit factor)
        """
        results = {}
        for coin in self.df['strategy'].columns:
            winning_trades = (self.df['overall_session_return', coin] > 0).sum()
            total_trades = math.ceil(self.df['session', coin].iloc[-1] / 2) #we divide by 2 because a session can indicates being in a trade and not being in a trade
            results[coin] = winning_trades / total_trades

        return results
    
    def calculate_daily_win_rate(self):
        """
        Typically >50% in both strategies.
        """
        results = {}
        #Note that the winrate that qs uses is using the daily returns. However, we are looking for returns per trade.
        # Therefore, this should be changed. 
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.win_rate(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_avg_win(self):
        """
        """
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.avg_win(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_avg_loss(self):
        """
        """
        # this is a comment
        results = {}
        for coin in self.df['strategy'].columns:
            results[coin] = qs.stats.avg_loss(self.df['strategy', coin].apply(np.exp) - 1)

        return results
    
    def calculate_avg_return_per_trade(self):
        """
        This reflects the average return per trade = total PnL / number of trades

        Typically Positive, typically >2% for trend-following, >1% for mean-reversion.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            active_trades = self.df[self.df['position', coin] == 1]
            results[coin] = active_trades['overall_session_return', coin].mean()

        return results

    def calculate_percentage_expectancy(self):
        """
        This calculates the expectancy of the strategy per coin.
        Expectancy = (Win Rate * Average Win) - (Losing Rate * Average Loss)

        Typically any expectancy greater than 0 is considered good (it depends on the number of trades).
        """
        results = {}
        for coin in self.df['strategy'].columns:
            win_rate = self.calculate_trades_win_rate()[coin]
            losing_rate = 1 - win_rate
            average_win = self.df[(self.df['position', coin] == 1) & (self.df['overall_session_return', coin] >= 0)]['overall_session_return', coin].mean()
            average_loss = self.df[(self.df['position', coin] == 1) & (self.df['overall_session_return', coin] <= 0)]['overall_session_return', coin].mean()
            expectancy = (win_rate * average_win) - (losing_rate * average_loss)
            results[coin] = expectancy

        return results  
    
    def calculate_monthly_expectancy(self):
        """
        Typically: 4-6% monthly in bullish, lower for mean-reversion in bearish.
        """
        results = {}
        for coin in self.df['strategy'].columns:
            total_trades = math.ceil(self.df['session', coin].iloc[-1] / 2)
            results[coin] = self.calculate_percentage_expectancy()[coin] * (total_trades / 12)

        return results

# %%
#Testing the metrics class
metrics = Metrics(test)

# %%
metrics.tp_year['BTCUSDT']
# Out:
# 9816.09375

# %%
metrics.print_performance('BTCUSDT')
# Out:
# ====================================================================================================
#
#
# All coins: ['BTCUSDT', 'ETHUSDT']
#
#
# From all available coins: BTCUSDT was chosen
# ----------------------------------------------------------------------------------------------------
#
#
# PERFORMANCE MEASURES:
#
#
# Multiple (Strategy):         1.081153
# Multiple (Buy-and-Hold):     1.411575
# --------------------------------------
# Out-/Underperformance:       -0.330422
#
#
# CAGR:                        34.163901
# Annualized Mean:             3.579105
# Annualized Std:              0.92231
# Sharpe Ratio:                0.834948
# Sortino Ratio:               1.233811
# Maximum Drawdown:            -0.153172
# Calmar Ratio:                223.042513
# Max Drawdown Duration:       5 Days
# Average Drawdown Duration:   0 Days
# Volatility:                  0.177448 Days
# Win Rate:                    0.8
# Daily Win Rate:              0.5
# Average Win:                 0.011479
# Average Loss:                -0.009661
# Average Return per Trade:    -0.006833
# Percentage Expectancy:       0.002149
# Monthly Expectancy:          0.008777
# Kelly Criterion:             0.079197
# ====================================================================================================

# %% [markdown]
# ---

# %% [markdown]
# ## Column Merger

# %% [markdown]
# The main use would be to merge columns that have common name (ex: 'exit_signal_1', 'exit_signal_2', 'exit_signal_3', ... the common name would 'exit_signal').
#
# The common name to look for should be provided

# %%
num_rows = len(test)
test['exit_signal_1'] = np.random.choice([0, 1], size = num_rows)
test['exit_signal_2'] = np.random.choice([0, 1], size = num_rows)

# %%
common = 'exit_signal'
exit_cols = [col for col in test.columns if common in col]

test[common] = test[exit_cols].sum(axis = 1).clip(0, 1)

# %%
test[common]
# Out:
# date                 coin
# 2021-01-01 01:00:00  BTCUSDT    1
#                      ETHUSDT    1
# 2021-01-01 02:00:00  BTCUSDT    1
#                      ETHUSDT    0
# 2021-01-01 03:00:00  BTCUSDT    1
#                                ..
# 2021-01-09 21:00:00  ETHUSDT    1
# 2021-01-09 22:00:00  BTCUSDT    0
#                      ETHUSDT    1
# 2021-01-09 23:00:00  BTCUSDT    0
#                      ETHUSDT    1
# Name: exit_signal, Length: 430, dtype: int64

# %% [markdown]
# Putting all together

# %%
def merge_cols(df, common = 'exit_signal', use_clip = True):
    cols = [col for col in df.columns if common in col]
    df[common] = df[cols].sum(axis = 1)
    if use_clip:
        df[common] = df[common].clip(0, 1)    
    return df

# %%
merge_cols(test, common)
# Out:
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT
\
# date                coin
# 2021-01-01 01:00:00 BTCUSDT                0.000000              0
#                     ETHUSDT                0.000000              1
# 2021-01-01 02:00:00 BTCUSDT                0.000000              1
#                     ETHUSDT                0.000000              0
# 2021-01-01 03:00:00 BTCUSDT                0.002873              0
# ...                                             ...            ...
# 2021-01-09 21:00:00 ETHUSDT                0.000000              1
# 2021-01-09 22:00:00 BTCUSDT                0.000000              0
#                     ETHUSDT                0.000000              1
# 2021-01-09 23:00:00 BTCUSDT               -0.004777              0
#                     ETHUSDT               -0.008213              1
#
#                              exit_signal_2  exit_signal
# date                coin
# 2021-01-01 01:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            1
# 2021-01-01 02:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            0
# 2021-01-01 03:00:00 BTCUSDT              1            1
# ...                                    ...          ...
# 2021-01-09 21:00:00 ETHUSDT              0            1
# 2021-01-09 22:00:00 BTCUSDT              0            0
#                     ETHUSDT              1            1
# 2021-01-09 23:00:00 BTCUSDT              0            0
#                     ETHUSDT              0            1
#
# [430 rows x 19 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## Downsampling

# %%
test
# Out:
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  29409.99  1.014308  29470.00    0.014207
#                     ETHUSDT    748.28  1.019358    749.00    0.019173
# 2021-01-01 02:00:00 BTCUSDT  29194.65  1.006881  29465.26   -0.007349
#                     ETHUSDT    744.06  1.013609    749.00   -0.005656
# 2021-01-01 03:00:00 BTCUSDT  29278.40  1.009770  29367.00    0.002865
# ...                               ...       ...       ...         ...
# 2021-01-09 21:00:00 ETHUSDT   1287.96  1.754547   1294.18    0.013145
# 2021-01-09 22:00:00 BTCUSDT  40281.09  1.389236  40743.47   -0.010808
#                     ETHUSDT   1286.61  1.752708   1304.37   -0.001049
# 2021-01-09 23:00:00 BTCUSDT  40088.22  1.382585  40415.01   -0.004800
#                     ETHUSDT   1276.00  1.738254   1292.74   -0.008281
#
#                                   low      open  position     price   returns  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  28960.35  28995.13         0  29409.99  0.014308
#                     ETHUSDT    733.37    734.08         0    748.28  0.019358
# 2021-01-01 02:00:00 BTCUSDT  29120.03  29410.00         1  29194.65 -0.007322
#                     ETHUSDT    742.27    748.27         1    744.06 -0.005640
# 2021-01-01 03:00:00 BTCUSDT  29150.02  29195.25         0  29278.40  0.002869
# ...                               ...       ...       ...       ...       ...
# 2021-01-09 21:00:00 ETHUSDT   1261.50   1271.14         0   1287.96  0.013232
# 2021-01-09 22:00:00 BTCUSDT  40120.00  40718.81         1  40281.09 -0.010750
#                     ETHUSDT   1276.32   1287.95         1   1286.61 -0.001048
# 2021-01-09 23:00:00 BTCUSDT  39928.91  40283.73         1  40088.22 -0.004788
#                     ETHUSDT   1266.85   1286.65         1   1276.00 -0.008246
#
#                              strategy  trades         volume  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT       NaN     0.0    5403.068471
#                     ETHUSDT       NaN     0.0   52336.187790
# 2021-01-01 02:00:00 BTCUSDT -0.000000     1.0    2384.231560
#                     ETHUSDT -0.000000     1.0   33019.501000
# 2021-01-01 03:00:00 BTCUSDT  0.002869     1.0    1461.345077
# ...                               ...     ...            ...
# 2021-01-09 21:00:00 ETHUSDT  0.000000     0.0  139273.226010
# 2021-01-09 22:00:00 BTCUSDT -0.000000     1.0    1973.252287
#                     ETHUSDT -0.000000     1.0   84360.715870
# 2021-01-09 23:00:00 BTCUSDT -0.004788     0.0    3255.535761
#                     ETHUSDT -0.008246     0.0   64558.955790
#
#                              volume_in_dollars  session  session_compound  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT       1.589042e+08      0.0               NaN
#                     ETHUSDT       3.916212e+07      0.0               NaN
# 2021-01-01 02:00:00 BTCUSDT       6.960681e+07      0.0          1.000000
#                     ETHUSDT       2.456849e+07      0.0          1.000000
# 2021-01-01 03:00:00 BTCUSDT       4.278585e+07      1.0          1.002873
# ...                                        ...      ...               ...
# 2021-01-09 21:00:00 ETHUSDT       1.793783e+08    106.0          1.000000
# 2021-01-09 22:00:00 BTCUSDT       7.948475e+07     96.0          1.000000
#                     ETHUSDT       1.085393e+08    106.0          1.000000
# 2021-01-09 23:00:00 BTCUSDT       1.305086e+08     97.0          0.995223
#                     ETHUSDT       8.237723e+07    107.0          0.991787
#
#                              overall_session_return  exit_signal_1  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT                0.000000              0
#                     ETHUSDT                0.000000              1
# 2021-01-01 02:00:00 BTCUSDT                0.000000              1
#                     ETHUSDT                0.000000              0
# 2021-01-01 03:00:00 BTCUSDT                0.002873              0
# ...                                             ...            ...
# 2021-01-09 21:00:00 ETHUSDT                0.000000              1
# 2021-01-09 22:00:00 BTCUSDT                0.000000              0
#                     ETHUSDT                0.000000              1
# 2021-01-09 23:00:00 BTCUSDT               -0.004777              0
#                     ETHUSDT               -0.008213              1
#
#                              exit_signal_2  exit_signal
# date                coin
# 2021-01-01 01:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            1
# 2021-01-01 02:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            0
# 2021-01-01 03:00:00 BTCUSDT              1            1
# ...                                    ...          ...
# 2021-01-09 21:00:00 ETHUSDT              0            1
# 2021-01-09 22:00:00 BTCUSDT              0            0
#                     ETHUSDT              1            1
# 2021-01-09 23:00:00 BTCUSDT              0            0
#                     ETHUSDT              0            1
#
# [430 rows x 19 columns]

# %%
# Resample with specific aggregation for OHLCV
df_1 = test.dropna()
df_daily = df_1.groupby(level = -1).resample('D', level = 0).agg({
    'open': 'first',    # First value of the day
    'high': 'max',      # Maximum value of the day
    'low': 'min',       # Minimum value of the day
    'close': 'last',    # Last value of the day
    'volume': 'sum'     # Total volume of the day
})

# %%
df_daily.columns = [f'daily_{col}' for col in df_daily.columns]

# %%
df_daily = df_daily.reorder_levels([1, 0], axis = 0).sort_index(axis = 0)

# %%
df_daily
# Out:
#                     daily_open  daily_high  daily_low  daily_close  \
# date       coin
# 2021-01-01 BTCUSDT    29410.00    29600.00   28624.57     29331.69
#            ETHUSDT      748.27      749.00     714.29       728.91
# 2021-01-02 BTCUSDT    29331.70    33300.00   28946.53     32178.33
#            ETHUSDT      728.91      787.69     714.91       774.56
# 2021-01-03 BTCUSDT    32176.45    34778.11   31962.99     33000.05
#            ETHUSDT      774.44     1011.07     768.71       978.28
# 2021-01-04 BTCUSDT    33000.05    33600.00   28130.00     31988.71
#            ETHUSDT      978.33     1162.97     890.00      1041.43
# 2021-01-05 BTCUSDT    31989.75    34360.00   29900.00     33949.53
#            ETHUSDT     1041.45     1134.60     974.45      1099.56
# 2021-01-06 BTCUSDT    33949.53    36939.21   33288.00     36769.36
#            ETHUSDT     1100.16     1213.00    1057.26      1208.42
# 2021-01-07 BTCUSDT    36769.36    40365.00   36300.00     39432.28
#            ETHUSDT     1208.75     1289.00    1131.00      1224.87
# 2021-01-08 BTCUSDT    39432.48    41950.00   36500.00     40582.81
#            ETHUSDT     1224.86     1273.75    1065.00      1216.93
# 2021-01-09 BTCUSDT    40586.96    41380.00   38720.00     40088.22
#            ETHUSDT     1216.72     1304.37    1171.36      1276.00
#
#                     daily_volume
# date       coin
# 2021-01-01 BTCUSDT  4.646805e+04
#            ETHUSDT  5.948452e+05
# 2021-01-02 BTCUSDT  1.299939e+05
#            ETHUSDT  1.352619e+06
# 2021-01-03 BTCUSDT  1.209576e+05
#            ETHUSDT  2.813604e+06
# 2021-01-04 BTCUSDT  1.408999e+05
#            ETHUSDT  4.245011e+06
# 2021-01-05 BTCUSDT  1.160500e+05
#            ETHUSDT  2.706996e+06
# 2021-01-06 BTCUSDT  1.271392e+05
#            ETHUSDT  2.390137e+06
# 2021-01-07 BTCUSDT  1.328257e+05
#            ETHUSDT  1.972923e+06
# 2021-01-08 BTCUSDT  1.397900e+05
#            ETHUSDT  2.131173e+06
# 2021-01-09 BTCUSDT  7.578598e+04
#            ETHUSDT  1.448871e+06

# %%
df = pd.merge(test, df_daily, left_index=True, right_index=True, how='outer')
df
# Out:
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT       NaN       NaN       NaN         NaN
#                     ETHUSDT       NaN       NaN       NaN         NaN
# 2021-01-01 01:00:00 BTCUSDT  29409.99  1.014308  29470.00    0.014207
#                     ETHUSDT    748.28  1.019358    749.00    0.019173
# 2021-01-01 02:00:00 BTCUSDT  29194.65  1.006881  29465.26   -0.007349
# ...                               ...       ...       ...         ...
# 2021-01-09 21:00:00 ETHUSDT   1287.96  1.754547   1294.18    0.013145
# 2021-01-09 22:00:00 BTCUSDT  40281.09  1.389236  40743.47   -0.010808
#                     ETHUSDT   1286.61  1.752708   1304.37   -0.001049
# 2021-01-09 23:00:00 BTCUSDT  40088.22  1.382585  40415.01   -0.004800
#                     ETHUSDT   1276.00  1.738254   1292.74   -0.008281
#
#                                   low      open  position     price   returns  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT       NaN       NaN       NaN       NaN       NaN
#                     ETHUSDT       NaN       NaN       NaN       NaN       NaN
# 2021-01-01 01:00:00 BTCUSDT  28960.35  28995.13       0.0  29409.99  0.014308
#                     ETHUSDT    733.37    734.08       0.0    748.28  0.019358
# 2021-01-01 02:00:00 BTCUSDT  29120.03  29410.00       1.0  29194.65 -0.007322
# ...                               ...       ...       ...       ...       ...
# 2021-01-09 21:00:00 ETHUSDT   1261.50   1271.14       0.0   1287.96  0.013232
# 2021-01-09 22:00:00 BTCUSDT  40120.00  40718.81       1.0  40281.09 -0.010750
#                     ETHUSDT   1276.32   1287.95       1.0   1286.61 -0.001048
# 2021-01-09 23:00:00 BTCUSDT  39928.91  40283.73       1.0  40088.22 -0.004788
#                     ETHUSDT   1266.85   1286.65       1.0   1276.00 -0.008246
#
#                              strategy  ...  session_compound  \
# date                coin               ...
# 2021-01-01 00:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
# 2021-01-01 01:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
# 2021-01-01 02:00:00 BTCUSDT -0.000000  ...          1.000000
# ...                               ...  ...               ...
# 2021-01-09 21:00:00 ETHUSDT  0.000000  ...          1.000000
# 2021-01-09 22:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-09 23:00:00 BTCUSDT -0.004788  ...          0.995223
#                     ETHUSDT -0.008246  ...          0.991787
#
#                              overall_session_return  exit_signal_1  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT                     NaN            NaN
#                     ETHUSDT                     NaN            NaN
# 2021-01-01 01:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 02:00:00 BTCUSDT                0.000000            1.0
# ...                                             ...            ...
# 2021-01-09 21:00:00 ETHUSDT                0.000000            1.0
# 2021-01-09 22:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-09 23:00:00 BTCUSDT               -0.004777            0.0
#                     ETHUSDT               -0.008213            1.0
#
#                              exit_signal_2  exit_signal  daily_open  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT            NaN          NaN    29410.00
#                     ETHUSDT            NaN          NaN      748.27
# 2021-01-01 01:00:00 BTCUSDT            1.0          1.0         NaN
#                     ETHUSDT            0.0          1.0         NaN
# 2021-01-01 02:00:00 BTCUSDT            1.0          1.0         NaN
# ...                                    ...          ...         ...
# 2021-01-09 21:00:00 ETHUSDT            0.0          1.0         NaN
# 2021-01-09 22:00:00 BTCUSDT            0.0          0.0         NaN
#                     ETHUSDT            1.0          1.0         NaN
# 2021-01-09 23:00:00 BTCUSDT            0.0          0.0         NaN
#                     ETHUSDT            0.0          1.0         NaN
#
#                              daily_high  daily_low  daily_close   daily_volume
# date                coin
# 2021-01-01 00:00:00 BTCUSDT     29600.0   28624.57     29331.69   46468.045095
#                     ETHUSDT       749.0     714.29       728.91  594845.206660
# 2021-01-01 01:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-01 02:00:00 BTCUSDT         NaN        NaN          NaN            NaN
# ...                                 ...        ...          ...            ...
# 2021-01-09 21:00:00 ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-09 22:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-09 23:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
#
# [432 rows x 24 columns]

# %%
_df = pd.concat([test, df_daily], axis = 1)
_df
# Out:
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  29409.99  1.014308  29470.00    0.014207
#                     ETHUSDT    748.28  1.019358    749.00    0.019173
# 2021-01-01 02:00:00 BTCUSDT  29194.65  1.006881  29465.26   -0.007349
#                     ETHUSDT    744.06  1.013609    749.00   -0.005656
# 2021-01-01 03:00:00 BTCUSDT  29278.40  1.009770  29367.00    0.002865
# ...                               ...       ...       ...         ...
# 2021-01-09 22:00:00 ETHUSDT   1286.61  1.752708   1304.37   -0.001049
# 2021-01-09 23:00:00 BTCUSDT  40088.22  1.382585  40415.01   -0.004800
#                     ETHUSDT   1276.00  1.738254   1292.74   -0.008281
# 2021-01-01 00:00:00 BTCUSDT       NaN       NaN       NaN         NaN
#                     ETHUSDT       NaN       NaN       NaN         NaN
#
#                                   low      open  position     price   returns  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT  28960.35  28995.13       0.0  29409.99  0.014308
#                     ETHUSDT    733.37    734.08       0.0    748.28  0.019358
# 2021-01-01 02:00:00 BTCUSDT  29120.03  29410.00       1.0  29194.65 -0.007322
#                     ETHUSDT    742.27    748.27       1.0    744.06 -0.005640
# 2021-01-01 03:00:00 BTCUSDT  29150.02  29195.25       0.0  29278.40  0.002869
# ...                               ...       ...       ...       ...       ...
# 2021-01-09 22:00:00 ETHUSDT   1276.32   1287.95       1.0   1286.61 -0.001048
# 2021-01-09 23:00:00 BTCUSDT  39928.91  40283.73       1.0  40088.22 -0.004788
#                     ETHUSDT   1266.85   1286.65       1.0   1276.00 -0.008246
# 2021-01-01 00:00:00 BTCUSDT       NaN       NaN       NaN       NaN       NaN
#                     ETHUSDT       NaN       NaN       NaN       NaN       NaN
#
#                              strategy  ...  session_compound  \
# date                coin               ...
# 2021-01-01 01:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
# 2021-01-01 02:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 03:00:00 BTCUSDT  0.002869  ...          1.002873
# ...                               ...  ...               ...
# 2021-01-09 22:00:00 ETHUSDT -0.000000  ...          1.000000
# 2021-01-09 23:00:00 BTCUSDT -0.004788  ...          0.995223
#                     ETHUSDT -0.008246  ...          0.991787
# 2021-01-01 00:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
#
#                              overall_session_return  exit_signal_1  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 02:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            0.0
# 2021-01-01 03:00:00 BTCUSDT                0.002873            0.0
# ...                                             ...            ...
# 2021-01-09 22:00:00 ETHUSDT                0.000000            1.0
# 2021-01-09 23:00:00 BTCUSDT               -0.004777            0.0
#                     ETHUSDT               -0.008213            1.0
# 2021-01-01 00:00:00 BTCUSDT                     NaN            NaN
#                     ETHUSDT                     NaN            NaN
#
#                              exit_signal_2  exit_signal  daily_open  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT            1.0          1.0         NaN
#                     ETHUSDT            0.0          1.0         NaN
# 2021-01-01 02:00:00 BTCUSDT            1.0          1.0         NaN
#                     ETHUSDT            0.0          0.0         NaN
# 2021-01-01 03:00:00 BTCUSDT            1.0          1.0         NaN
# ...                                    ...          ...         ...
# 2021-01-09 22:00:00 ETHUSDT            1.0          1.0         NaN
# 2021-01-09 23:00:00 BTCUSDT            0.0          0.0         NaN
#                     ETHUSDT            0.0          1.0         NaN
# 2021-01-01 00:00:00 BTCUSDT            NaN          NaN    29410.00
#                     ETHUSDT            NaN          NaN      748.27
#
#                              daily_high  daily_low  daily_close   daily_volume
# date                coin
# 2021-01-01 01:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-01 02:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-01 03:00:00 BTCUSDT         NaN        NaN          NaN            NaN
# ...                                 ...        ...          ...            ...
# 2021-01-09 22:00:00 ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-09 23:00:00 BTCUSDT         NaN        NaN          NaN            NaN
#                     ETHUSDT         NaN        NaN          NaN            NaN
# 2021-01-01 00:00:00 BTCUSDT     29600.0   28624.57     29331.69   46468.045095
#                     ETHUSDT       749.0     714.29       728.91  594845.206660
#
# [432 rows x 24 columns]

# %%
_df_1 = test.join(df_daily, how = 'outer')
_df_1 = _df_1.unstack().ffill().stack()
_df_1.head()
# Out:
# C:\Users\yassi\AppData\Local\Temp\ipykernel_26900\4265171606.py:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   _df_1 = _df_1.unstack().ffill().stack()
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT       NaN       NaN       NaN         NaN
#                     ETHUSDT       NaN       NaN       NaN         NaN
# 2021-01-01 01:00:00 BTCUSDT  29409.99  1.014308  29470.00    0.014207
#                     ETHUSDT    748.28  1.019358    749.00    0.019173
# 2021-01-01 02:00:00 BTCUSDT  29194.65  1.006881  29465.26   -0.007349
#                     ETHUSDT    744.06  1.013609    749.00   -0.005656
# 2021-01-01 03:00:00 BTCUSDT  29278.40  1.009770  29367.00    0.002865
#                     ETHUSDT    744.82  1.014644    747.23    0.001021
# 2021-01-01 04:00:00 BTCUSDT  29220.31  1.007766  29395.00   -0.001986
#                     ETHUSDT    742.29  1.011198    747.09   -0.003403
# 2021-01-01 05:00:00 BTCUSDT  29187.01  1.006618  29235.28   -0.001140
#                     ETHUSDT    740.65  1.008964    743.23   -0.002212
# 2021-01-01 06:00:00 BTCUSDT  29174.35  1.006181  29270.00   -0.000434
#                     ETHUSDT    739.97  1.008037    743.25   -0.000919
# 2021-01-01 07:00:00 BTCUSDT  29092.83  1.003370  29191.98   -0.002798
#                     ETHUSDT    737.38  1.004509    740.51   -0.003506
# 2021-01-01 08:00:00 BTCUSDT  29000.01  1.000168  29178.03   -0.003196
#                     ETHUSDT    730.07  0.994551    738.48   -0.009963
# 2021-01-01 09:00:00 BTCUSDT  29202.21  1.007142  29307.73    0.006948
#                     ETHUSDT    733.68  0.999469    734.77    0.004933
# 2021-01-01 10:00:00 BTCUSDT  29223.82  1.007887  29344.97    0.000740
#                     ETHUSDT    736.81  1.003733    738.87    0.004257
# 2021-01-01 11:00:00 BTCUSDT  29313.49  1.010980  29402.57    0.003064
#                     ETHUSDT    738.85  1.006512    741.76    0.002765
#                     ETHUSDT    734.40    739.87       1.0    737.38 -0.003500
# 2021-01-01 08:00:00 BTCUSDT  28872.24  29092.84       1.0  29000.01 -0.003190
#                     ETHUSDT    725.10    737.37       1.0    730.07 -0.009913
# 2021-01-01 09:00:00 BTCUSDT  28970.00  29000.01       0.0  29202.21  0.006972
#                     ETHUSDT    728.77    730.07       0.0    733.68  0.004945
# 2021-01-01 10:00:00 BTCUSDT  29152.88  29202.21       0.0  29223.82  0.000740
#                     ETHUSDT    733.27    733.69       0.0    736.81  0.004266
# 2021-01-01 11:00:00 BTCUSDT  29212.44  29223.82       0.0  29313.49  0.003068
#                     ETHUSDT    736.11    736.82       0.0    738.85  0.002769
# 2021-01-01 12:00:00 BTCUSDT  29150.00  29313.49       1.0  29233.49 -0.002729
#                     ETHUSDT    732.12    738.85       1.0    733.19 -0.007661
# 2021-01-01 13:00:00 BTCUSDT  29200.00  29233.49       0.0  29464.79  0.007912
#                     ETHUSDT    733.00    733.19       0.0    740.08  0.009397
# 2021-01-01 14:00:00 BTCUSDT  29266.15  29464.79       1.0  29327.84 -0.004648
#                     ETHUSDT    736.46    740.08       1.0    738.00 -0.002811
# 2021-01-01 15:00:00 BTCUSDT  29030.14  29327.83       1.0  29188.67 -0.004745
#                     ETHUSDT    733.50    738.01       1.0    735.39 -0.003537
# 2021-01-01 16:00:00 BTCUSDT  29125.00  29188.67       0.0  29300.57  0.003834
#                     ETHUSDT    733.01    735.39       0.0    735.83  0.000598
# 2021-01-01 17:00:00 BTCUSDT  28937.00  29300.79       1.0  29079.64 -0.007540
#                     ETHUSDT    726.57    735.76       1.0    727.94 -0.010723
# 2021-01-01 18:00:00 BTCUSDT  28624.57  29077.59       1.0  29072.70 -0.000239
#                     ETHUSDT    714.29    727.94       1.0    724.60 -0.004588
# 2021-01-01 19:00:00 BTCUSDT  28950.00  29072.70       1.0  29029.04 -0.001502
#                     ETHUSDT    720.95    724.57       0.0    725.34  0.001021
# 2021-01-01 20:00:00 BTCUSDT  28880.37  29029.04       0.0  29200.96  0.005922
#                     ETHUSDT    722.50    725.34       0.0    729.48  0.005708
# 2021-01-01 21:00:00 BTCUSDT  29130.00  29200.97       1.0  29160.39 -0.001389
#                     ETHUSDT    726.69    729.48       1.0    728.23 -0.001714
# 2021-01-01 22:00:00 BTCUSDT  29104.57  29163.17       0.0  29262.32  0.003495
#                     ETHUSDT    725.65    728.23       0.0    728.90  0.000920
# 2021-01-01 23:00:00 BTCUSDT  29228.14  29262.32       0.0  29331.69  0.002371
#                     ETHUSDT    727.65    728.97       0.0    728.91  0.000014
# 2021-01-02 00:00:00 BTCUSDT  28946.53  29331.70       1.0  29197.48 -0.004576
#                     ETHUSDT    716.26    728.91       1.0    719.90 -0.012361
#
#                              strategy  ...  session_compound  \
# date                coin               ...
# 2021-01-01 00:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
# 2021-01-01 01:00:00 BTCUSDT       NaN  ...               NaN
#                     ETHUSDT       NaN  ...               NaN
# 2021-01-01 02:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 03:00:00 BTCUSDT  0.002869  ...          1.002873
#                     ETHUSDT  0.001021  ...          1.001022
# 2021-01-01 04:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 05:00:00 BTCUSDT -0.001140  ...          0.998861
#                     ETHUSDT -0.002209  ...          0.997793
# 2021-01-01 06:00:00 BTCUSDT -0.000434  ...          0.998428
#                     ETHUSDT -0.000918  ...          0.996877
# 2021-01-01 07:00:00 BTCUSDT -0.002794  ...          0.995642
#                     ETHUSDT -0.003500  ...          0.993394
# 2021-01-01 08:00:00 BTCUSDT -0.003190  ...          0.992470
#                     ETHUSDT -0.009913  ...          0.983595
# 2021-01-01 09:00:00 BTCUSDT  0.006972  ...          0.999414
#                     ETHUSDT  0.004945  ...          0.988471
# 2021-01-01 10:00:00 BTCUSDT  0.000000  ...          1.000000
#                     ETHUSDT  0.000000  ...          1.000000
# 2021-01-01 11:00:00 BTCUSDT  0.000000  ...          1.000000
#                     ETHUSDT  0.000000  ...          1.000000
# 2021-01-01 12:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 13:00:00 BTCUSDT  0.007912  ...          1.007944
#                     ETHUSDT  0.009397  ...          1.009442
# 2021-01-01 14:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 15:00:00 BTCUSDT -0.004745  ...          0.995266
#                     ETHUSDT -0.003537  ...          0.996470
# 2021-01-01 16:00:00 BTCUSDT  0.003834  ...          0.999089
#                     ETHUSDT  0.000598  ...          0.997066
# 2021-01-01 17:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 18:00:00 BTCUSDT -0.000239  ...          0.999761
#                     ETHUSDT -0.004588  ...          0.995422
# 2021-01-01 19:00:00 BTCUSDT -0.001502  ...          0.998261
#                     ETHUSDT  0.001021  ...          0.996439
# 2021-01-01 20:00:00 BTCUSDT  0.005922  ...          1.004191
#                     ETHUSDT  0.000000  ...          1.000000
# 2021-01-01 21:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
# 2021-01-01 22:00:00 BTCUSDT  0.003495  ...          1.003502
#                     ETHUSDT  0.000920  ...          1.000920
# 2021-01-01 23:00:00 BTCUSDT  0.000000  ...          1.000000
#                     ETHUSDT  0.000000  ...          1.000000
# 2021-01-02 00:00:00 BTCUSDT -0.000000  ...          1.000000
#                     ETHUSDT -0.000000  ...          1.000000
#
#                              overall_session_return  exit_signal_1  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT                     NaN            NaN
#                     ETHUSDT                     NaN            NaN
# 2021-01-01 01:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 02:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            0.0
# 2021-01-01 03:00:00 BTCUSDT                0.002873            0.0
#                     ETHUSDT                0.001022            1.0
# 2021-01-01 04:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 05:00:00 BTCUSDT               -0.000586            1.0
#                     ETHUSDT               -0.011529            1.0
# 2021-01-01 06:00:00 BTCUSDT               -0.000586            1.0
#                     ETHUSDT               -0.011529            0.0
# 2021-01-01 07:00:00 BTCUSDT               -0.000586            0.0
#                     ETHUSDT               -0.011529            1.0
# 2021-01-01 08:00:00 BTCUSDT               -0.000586            0.0
#                     ETHUSDT               -0.011529            1.0
# 2021-01-01 09:00:00 BTCUSDT               -0.000586            0.0
#                     ETHUSDT               -0.011529            1.0
# 2021-01-01 10:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 11:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            0.0
# 2021-01-01 12:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            0.0
# 2021-01-01 13:00:00 BTCUSDT                0.007944            1.0
#                     ETHUSDT                0.009442            1.0
# 2021-01-01 14:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 15:00:00 BTCUSDT               -0.000911            0.0
#                     ETHUSDT               -0.002934            0.0
# 2021-01-01 16:00:00 BTCUSDT               -0.000911            0.0
#                     ETHUSDT               -0.002934            1.0
# 2021-01-01 17:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            0.0
# 2021-01-01 18:00:00 BTCUSDT                0.004191            0.0
#                     ETHUSDT               -0.003561            0.0
# 2021-01-01 19:00:00 BTCUSDT                0.004191            1.0
#                     ETHUSDT               -0.003561            0.0
# 2021-01-01 20:00:00 BTCUSDT                0.004191            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 21:00:00 BTCUSDT                0.000000            0.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-01 22:00:00 BTCUSDT                0.003502            1.0
#                     ETHUSDT                0.000920            1.0
# 2021-01-01 23:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            1.0
# 2021-01-02 00:00:00 BTCUSDT                0.000000            1.0
#                     ETHUSDT                0.000000            0.0
#
#                              exit_signal_2  exit_signal  daily_open  \
# date                coin
# 2021-01-01 00:00:00 BTCUSDT            NaN          NaN    29410.00
#                     ETHUSDT            NaN          NaN      748.27
# 2021-01-01 01:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 02:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          0.0      748.27
# 2021-01-01 03:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 04:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 05:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 06:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 07:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 08:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 09:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 10:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 11:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            0.0          0.0      748.27
# 2021-01-01 12:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 13:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 14:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 15:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 16:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 17:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            0.0          0.0      748.27
# 2021-01-01 18:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 19:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 20:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 21:00:00 BTCUSDT            0.0          0.0    29410.00
#                     ETHUSDT            1.0          1.0      748.27
# 2021-01-01 22:00:00 BTCUSDT            1.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-01 23:00:00 BTCUSDT            0.0          1.0    29410.00
#                     ETHUSDT            0.0          1.0      748.27
# 2021-01-02 00:00:00 BTCUSDT            1.0          1.0    29331.70
#                     ETHUSDT            0.0          0.0      728.91
#
#                              daily_high  daily_low  daily_close  daily_volume
# date                coin
# 2021-01-01 00:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 01:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 02:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 03:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 04:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 05:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 06:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 07:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 08:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 09:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 10:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 11:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 12:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 13:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 14:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 15:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 16:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 17:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 18:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 19:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 20:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 21:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 22:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-01 23:00:00 BTCUSDT    29600.00   28624.57     29331.69  4.646805e+04
#                     ETHUSDT      749.00     714.29       728.91  5.948452e+05
# 2021-01-02 00:00:00 BTCUSDT    33300.00   28946.53     32178.33  1.299939e+05
#                     ETHUSDT      787.69     714.91       774.56  1.352619e+06
#
# [50 rows x 24 columns]

# %%
test
# Out:
#                                 close  creturns      high  log_return  \
# date                coin
# 2021-01-01 01:00:00 BTCUSDT
# 2021-01-01 03:00:00 BTCUSDT                0.002873              0
# ...                                             ...            ...
# 2021-01-09 21:00:00 ETHUSDT                0.000000              1
# 2021-01-09 22:00:00 BTCUSDT                0.000000              0
#                     ETHUSDT                0.000000              1
# 2021-01-09 23:00:00 BTCUSDT               -0.004777              0
#                     ETHUSDT               -0.008213              1
#
#                              exit_signal_2  exit_signal
# date                coin
# 2021-01-01 01:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            1
# 2021-01-01 02:00:00 BTCUSDT              1            1
#                     ETHUSDT              0            0
# 2021-01-01 03:00:00 BTCUSDT              1            1
# ...                                    ...          ...
# 2021-01-09 21:00:00 ETHUSDT              0            1
# 2021-01-09 22:00:00 BTCUSDT              0            0
#                     ETHUSDT              1            1
# 2021-01-09 23:00:00 BTCUSDT              0            0
#                     ETHUSDT              0            1
#
# [430 rows x 19 columns]

# %%
import vectorbt as vbt

# Download historical data (e.g., S&P 500)
benchmark_data = vbt.YFData.download('^GSPC', start='2000-01-01', end='2023-12-31')
prices = benchmark_data.get('Close')

# %%
import yfinance as yf

# Fetch 10-year Treasury yield (^TNX)
rf_data = yf.download('^TNX', start='2020-01-01', end='2024-12-31', progress=False)
rf_rate = rf_data['Close'] / 100  # Convert percentage to decimal
rf_rate.iloc[-1]
# Out:
# Ticker
# ^TNX    0.04619
# Name: 2024-12-27 00:00:00+00:00, dtype: float64

# %%
df_2 = test[['strategy']] * 2
df_2
# Out:
#                              strategy
# date                coin
# 2021-01-01 01:00:00 BTCUSDT       NaN
#                     ETHUSDT       NaN
# 2021-01-01 02:00:00 BTCUSDT -0.000000
#                     ETHUSDT -0.000000
# 2021-01-01 03:00:00 BTCUSDT  0.005737
# ...                               ...
# 2021-01-09 21:00:00 ETHUSDT  0.000000
# 2021-01-09 22:00:00 BTCUSDT -0.000000
#                     ETHUSDT -0.000000
# 2021-01-09 23:00:00 BTCUSDT -0.009576
#                     ETHUSDT -0.016493
#
# [430 rows x 1 columns]

# %%
dfs = [test, df_2]
columns  = []
for df in dfs:
    columns.append(df['strategy'])

strategies = pd.concat(columns, axis = 1)
strategies
# Out:
#                              strategy  strategy
# date                coin
# 2021-01-01 01:00:00 BTCUSDT       NaN       NaN
#                     ETHUSDT       NaN       NaN
# 2021-01-01 02:00:00 BTCUSDT -0.000000 -0.000000
#                     ETHUSDT -0.000000 -0.000000
# 2021-01-01 03:00:00 BTCUSDT  0.002869  0.005737
# ...                               ...       ...
# 2021-01-09 21:00:00 ETHUSDT  0.000000  0.000000
# 2021-01-09 22:00:00 BTCUSDT -0.000000 -0.000000
#                     ETHUSDT -0.000000 -0.000000
# 2021-01-09 23:00:00 BTCUSDT -0.004788 -0.009576
#                     ETHUSDT -0.008246 -0.016493
#
# [430 rows x 2 columns]

# %%
#Method 1
qs.stats.sharpe(test['strategy'].apply(np.exp) - 1)
# Out:
# 1.2607486739869787

# %%
#Method 2
from calculations import Metrics
metrics = Metrics(test)
all_sharpe = metrics.calculate_sharpe()

# %%
sum(all_sharpe.values()) / len(all_sharpe)
# Out:
# 1.2252879209112597
